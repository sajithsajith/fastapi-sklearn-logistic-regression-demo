# %%
from ML.preprocessing import load_data, split_data
from ML.train import train_model, predict_accuracy
from ML.visualization import visualize_data, display_descision_boundary

# %%
df = load_data("test/AR - performance review - cleaned.csv")

# %%
df
# Out:
#      #  CPT Code Insurance Company Physician Name Payment Amount   Balance  \
# 0    1   99213.0          Medicare      Dr. Smith         $0.00   $100.00
# 2    3   99215.0             Cigna        Dr. Lee         $0.00   $150.00
# 4    5   99212.0        Blue Cross        Dr. Kim         $0.00    $75.00
# 5    6   99213.0          Medicare      Dr. Smith         $0.00   $100.00
# 7    8   99215.0             Cigna        Dr. Lee         $0.00   $150.00
# 9   10   99212.0        Blue Cross        Dr. Kim         $0.00    $75.00
# 10  11   99213.0          Medicare      Dr. Smith         $0.00   $100.00
# 12  13   99215.0             Cigna        Dr. Lee         $0.00   $150.00
# 14  15   99212.0        Blue Cross        Dr. Kim         $0.00    $75.00
# 15  16   99213.0          Medicare      Dr. Smith         $0.00   $100.00
# 17  18   99215.0             Cigna        Dr. Lee         $0.00   $150.00
# 19  20   99212.0        Blue Cross        Dr. Kim         $0.00    $75.00
# ...

# %%
var = ["CPT Code", "Insurance Company", "Physician Name", "Payment Amount", "Balance"]
hue = "Denial Reason"
image_uri = visualize_data(df, var, hue)

# %%
from IPython.display import HTML

HTML(f'<img src="{image_uri}" style="max-width:1080px;">')
# Out:
# <img src="data:image/png;base64,..." style="max-width:1080px;">

# %%
feature_columns = ["CPT Code", "Balance"]
target_column = "Denial Reason"
X_train, X_test, y_train, y_test = split_data(
    df, feature_columns, target_column, 0.3, 123
)

# %%
y_test
# Out:
# array([1, 1, 1, 0, 2])

# %%
model = train_model(X_train, y_train)

# %%
model
# Out:
# LogisticRegression(random_state=0)

# %%
descision_boundary = display_descision_boundary(model, X_test, y_test, feature_columns)

# %%
HTML(f'<img src="{descision_boundary}" style="max-width:1080px;">')
# Out:
# <img src="data:image/png;base64,..." style="max-width:1080px;">
